# %%
# Loan Risk Analysis — Data Loading & Initial Inspection

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
RAW_DATA_PATH = r"C:\Users\lalit\Downloads\Loan project\data\raw\accepted_2007_to_2018Q4.csv"
OUTPUT_PATH = r"C:\Users\lalit\Downloads\Loan project\data\loan_raw.csv"

# %%
df = pd.read_csv(RAW_DATA_PATH, low_memory=False)

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (2260701, 151)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN    3600.00      3600.00          3600.00   36 months
# 1  68355089        NaN   24700.00     24700.00         24700.00   36 months
# 2  68341763        NaN   20000.00     20000.00         20000.00   60 months
# 3  66310712        NaN   35000.00     35000.00         35000.00   60 months
# 4  68476807        NaN   10400.00     10400.00         10400.00   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
df.isna().mean().sort_values(ascending=False).head(20)
# Out:
# member_id                                    1.00
# orig_projected_additional_accrued_interest   1.00
# hardship_end_date                            1.00
# hardship_start_date                          1.00
# hardship_type                                1.00
# hardship_reason                              1.00
# hardship_status                              1.00
# deferral_term                                1.00
# hardship_last_payment_amount                 1.00
# hardship_payoff_balance_amount               1.00
# hardship_loan_status                         1.00
# hardship_dpd                                 1.00
# hardship_length                              1.00
# payment_plan_start_date                      1.00
# hardship_amount                              1.00
# settlement_term                              0.98
# debt_settlement_flag_date                    0.98
# settlement_status                            0.98
# settlement_date                              0.98
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns.tolist()
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
# ...

# %%
df.to_csv(OUTPUT_PATH, index=False)

print("Raw data saved to:", OUTPUT_PATH)
# Out:
# Raw data saved to: C:\Users\lalit\Downloads\Loan project\data\loan_raw.csv
